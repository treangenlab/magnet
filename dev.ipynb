# %% [markdown]
# # Dependencies

# %%
import os
import argparse
import pathlib
import sys
import subprocess
import math
import warnings
from collections import defaultdict
from multiprocessing import Pool, Manager
from itertools import repeat
warnings.filterwarnings("ignore")

import pandas as pd
from ete3 import NCBITaxa
from Bio import SeqIO

# %%
from utils.reference_finder import prepare_reference_genomes
from utils.alignment import run_minimap2, run_bwa, sort_samfile, samtools_calculate_coverage
from utils.summary import alignment_summary, merge_reference_fasta, call_present_absent
from utils.ani import samtools_merged_consensus, ani_summary
from utils.input_parsing import parsing_input_f, filter_input_df, get_seq2assembly_dict

# %% [markdown]
# # Results

# %%
result_df = pd.read_csv('/home/Users/yl181/magnet/zymo_bowtie2_a_k2_0.002/magnet_results.csv')

# %%
result_df = call_present_absent(result_df, min_coverage_score=0.7)

# %%
result_df
# Out:
#     Taxonomy ID Assembly Accession ID         Source Database  \
# 0         96241       GCF_006094475.1  SOURCE_DATABASE_REFSEQ
# 1           287       GCF_000006765.1  SOURCE_DATABASE_REFSEQ
# 2         28901       GCF_000006945.2  SOURCE_DATABASE_REFSEQ
# 3          1280       GCF_000013425.1  SOURCE_DATABASE_REFSEQ
# 4          1639       GCF_000196035.1  SOURCE_DATABASE_REFSEQ
# 5          1351       GCF_001598635.1  SOURCE_DATABASE_REFSEQ
# 6          1613       GCF_029961225.1  SOURCE_DATABASE_REFSEQ
# 7           623       GCF_000006925.2  SOURCE_DATABASE_REFSEQ
# 8           562       GCF_000008865.2  SOURCE_DATABASE_REFSEQ
# 9          1642       GCF_009648575.1  SOURCE_DATABASE_REFSEQ
# 10        72361       GCF_003667885.1  SOURCE_DATABASE_REFSEQ
# 11      1654388       GCF_900636685.1  SOURCE_DATABASE_REFSEQ
# 12       483913       GCF_023238325.1  SOURCE_DATABASE_REFSEQ
# 13       260554       GCF_004006435.1  SOURCE_DATABASE_REFSEQ
# 14       227866       GCF_012225885.1  SOURCE_DATABASE_REFSEQ
# 15        72360       GCF_012648005.1  SOURCE_DATABASE_REFSEQ
# 16         1423       GCF_000009045.1  SOURCE_DATABASE_REFSEQ
# 17          573       GCF_000240185.1  SOURCE_DATABASE_REFSEQ
# 18      2892442       GCF_020911845.1  SOURCE_DATABASE_REFSEQ
# 19        54736       GCF_000439255.1  SOURCE_DATABASE_REFSEQ
# 20         1311       GCF_001552035.1  SOURCE_DATABASE_REFSEQ
# 21       208962       GCF_016904755.1  SOURCE_DATABASE_REFSEQ
# 22         1396       GCF_002220285.1  SOURCE_DATABASE_REFSEQ
# 23       164546       GCF_022406855.1  SOURCE_DATABASE_REFSEQ
# 24      2044467       GCF_005843885.1  SOURCE_DATABASE_REFSEQ
# 25      1499973       GCF_002900365.1  SOURCE_DATABASE_REFSEQ
# 26       492670       GCF_000769555.1  SOURCE_DATABASE_REFSEQ
# 27          564       GCF_020097475.1  SOURCE_DATABASE_REFSEQ
# 28         1352       GCF_009734005.1  SOURCE_DATABASE_REFSEQ
# 29        29385       GCF_007814115.1  SOURCE_DATABASE_REFSEQ
# 30        78331       GCF_000253375.1  SOURCE_DATABASE_REFSEQ
# 31        29382       GCF_003956025.1  SOURCE_DATABASE_REFSEQ
#
#     Is Representative   Assembly Level  \
# 0                True  Complete Genome
# 1                True  Complete Genome
# 2                True  Complete Genome
# 3                True  Complete Genome
# 4                True  Complete Genome
# 5               False  Complete Genome
# 6                True  Complete Genome
# 7                True  Complete Genome
# 8                True  Complete Genome
# 9                True  Complete Genome
# 10               True  Complete Genome
# 11               True  Complete Genome
# 12               True  Complete Genome
# 13               True  Complete Genome
# 14               True  Complete Genome
# 15               True  Complete Genome
# 16               True  Complete Genome
# 17               True  Complete Genome
# 18              False  Complete Genome
# 19               True  Complete Genome
# 20               True  Complete Genome
# 21               True  Complete Genome
# 22               True  Complete Genome
# 23              False  Complete Genome
# 24              False  Complete Genome
# 25              False  Complete Genome
# 26               True  Complete Genome
# 27               True  Complete Genome
# 28               True  Complete Genome
# 29               True  Complete Genome
# 30               True  Complete Genome
# 31              False  Complete Genome
#
#                                  Organism of Assembly  \
# 0            Bacillus spizizenii ATCC 6633 = JCM 2499
# 1                         Pseudomonas aeruginosa PAO1
# 2   Salmonella enterica subsp. enterica serovar Ty...
# 3       Staphylococcus aureus subsp. aureus NCTC 8325
# 4                        Listeria monocytogenes EGD-e
# 5                               Enterococcus faecalis
# 6                       Limosilactobacillus fermentum
# 7                       Shigella flexneri 2a str. 301
# 8                 Escherichia coli O157:H7 str. Sakai
# 9                                    Listeria innocua
# 10                              Bacillus vallismortis
# 11                         Staphylococcus schweitzeri
# 12                               Bacillus inaquosorum
# 13                              Bacillus halotolerans
# 14                               Bacillus tequilensis
# 15                                Bacillus mojavensis
# 16         Bacillus subtilis subsp. subtilis str. 168
# 17    Klebsiella pneumoniae subsp. pneumoniae HS11286
# 18                             Pseudomonas sp. CIP-10
# 19                         Salmonella bongori N268-08
# 20                           Streptococcus agalactiae
# 21                               Escherichia albertii
# 22                                    Bacillus cereus
# 23                            Cupriavidus taiwanensis
# 24                              Escherichia sp. E4742
# 25                               Escherichia marmotae
# 26                                Bacillus velezensis
# 27                             Escherichia fergusonii
# 28                               Enterococcus faecium
# 29                       Staphylococcus saprophyticus
# 30              Mycobacterium canettii CIPT 140010059
# 31                              Staphylococcus cohnii
#
#                         Strain  Total Length  Downloaded  \
# 0                    ATCC 6633     4045538.0        True
# 1                         PAO1     6264404.0        True
# 2                          LT2     4951383.0        True
# 3                    NCTC 8325     2821361.0        True
# 4                        EGD-e     2944528.0        True
# 5                         LD33     2803429.0        True
# 6                     EFEL6800     2103331.0        True
# 7                          301     4828820.0        True
# 8   Sakai substr. RIMD 0509952     5594605.0        True
# 9                  CFSAN044836     2922148.0        True
# 10                      Bac111     3958372.0        True
# 11                   NCTC13712     2784939.0        True
# 12                       A65.1     4242130.0        True
# 13                    ZB201702     4154245.0        True
# 14                   EA-CB0015     4012371.0        True
# 15                    UCMB5075     4031121.0        True
# 16                         168     4215606.0        True
# 17                     HS11286     5682322.0        True
# 18                      CIP-10     6473352.0        True
# 19                     N268-08     4773537.0        True
# 20                     NGBS128     2079123.0        True
# 21                  Sample 167     4631903.0        True
# 22                    FORC_047     5836971.0        True
# 23                    SWF66294     6782863.0        True
# 24                       E4742     5120753.0        True
# 25                    HT073016     4896291.0        True
# 26                       JS25R     4014440.0        True
# 27               FDAARGOS_1499     4645928.0        True
# 28                       SRR24     2919198.0        True
# 29                          1A     2635789.0        True
# 30              CIPT 140010059     4482059.0        True
# 31                FDAARGOS_538     2700845.0        True
#
#                           Species  ...  Secondary Expected  Secondary Score  \
# 0             Bacillus spizizenii  ...            1.000000         1.000000
# 1          Pseudomonas aeruginosa  ...            1.000000         0.967680
# 2             Salmonella enterica  ...            1.000000         0.935623
# 3           Staphylococcus aureus  ...            1.000000         0.921382
# 4          Listeria monocytogenes  ...            1.000000         0.931354
# 5           Enterococcus faecalis  ...            1.000000         0.890446
# 6   Limosilactobacillus fermentum  ...            1.000000         0.892914
# 7               Shigella flexneri  ...            1.000000         0.889687
# 8                Escherichia coli  ...            1.000000         0.808360
# 9                Listeria innocua  ...            1.000000         0.862307
# 10          Bacillus vallismortis  ...            1.000000         0.881393
# 11     Staphylococcus schweitzeri  ...            1.000000         0.861931
# 12           Bacillus inaquosorum  ...            1.000000         0.861323
# 13          Bacillus halotolerans  ...            1.000000         0.851494
# 14           Bacillus tequilensis  ...            1.000000         0.849856
# 15            Bacillus mojavensis  ...            1.000000         0.858009
# 16              Bacillus subtilis  ...            1.000000         0.862585
# 17          Klebsiella pneumoniae  ...            1.000000         0.426917
# 18         Pseudomonas sp. CIP-10  ...            1.000000         0.301415
# 19             Salmonella bongori  ...            1.000000         0.805211
# 20       Streptococcus agalactiae  ...            1.000000         0.055425
# 21           Escherichia albertii  ...            1.000000         0.800222
# 22                Bacillus cereus  ...            1.000000         0.053919
# 23        Cupriavidus taiwanensis  ...            0.997388         0.081080
# 24          Escherichia sp. E4742  ...            1.000000         0.770260
# 25           Escherichia marmotae  ...            1.000000         0.813909
# 26            Bacillus velezensis  ...            1.000000         0.390627
# 27         Escherichia fergusonii  ...            1.000000         0.699085
# 28           Enterococcus faecium  ...            1.000000         0.119192
# 29   Staphylococcus saprophyticus  ...            1.000000         0.231856
# 30         Mycobacterium canettii  ...            0.739821         0.011292
# 31          Staphylococcus cohnii  ...            1.000000         0.221629
#
#     Secondary Depth  Primary Breadth  Primary Expected  Primary Score  \
# 0        132.511000         0.999999          1.000000       0.999999
# 1         65.565285         0.967013          1.000000       0.967013
# 2         99.628887         0.928550          1.000000       0.928550
# 3        160.315715         0.917263          1.000000       0.917263
# 4        129.529645         0.911952          1.000000       0.911952
# 5        132.768305         0.889125          1.000000       0.889125
# 6        212.556811         0.885748          1.000000       0.885748
# 7        114.269365         0.786340          1.000000       0.786340
# 8         97.632873         0.712230          1.000000       0.712230
# 9        111.905010         0.536577          0.999999       0.536578
# 10       104.355670         0.203398          0.449790       0.452206
# 11       144.854998         0.430713          0.994473       0.433107
# 12       105.754378         0.223387          0.543606       0.410936
# 13        90.357620         0.143939          0.359235       0.400682
# 14       105.969970         0.183283          0.458545       0.399705
# 15        90.663038         0.128208          0.328128       0.390727
# 16       102.397199         0.193634          0.510101       0.379599
# 17        71.521912         0.088700          0.236148       0.375613
# 18        52.264418         0.056747          0.156827       0.361844
# 19        84.664805         0.274417          0.790406       0.347185
# 20       772.158157         0.018327          0.055622       0.329498
# 21        92.606287         0.200037          0.608517       0.328729
# 22       641.472836         0.017304          0.054238       0.319038
# 23        73.546897         0.014609          0.047258       0.309141
# 24       108.055180         0.274972          0.927370       0.296508
# 25        95.923526         0.220992          0.757247       0.291836
# 26        91.963779         0.073708          0.255968       0.287956
# 27        89.949381         0.257754          0.934275       0.275887
# 28       269.461884         0.046409          0.249496       0.186010
# 29       158.609517         0.066855          0.370481       0.180454
# 30       161.169516         0.001858          0.011227       0.165485
# 31       167.008188         0.062271          0.681949       0.091313
#
#     Primary Depth  Consensus ANI  Combined PS and ANI (Sqrt(ANI)xPSx100)  \
# 0       68.478268       0.999977                                  100.00
# 1       56.030159       0.994526                                   96.44
# 2       64.813931       0.989556                                   92.37
# 3       83.129377       0.993009                                   91.41
# 4       77.818246       0.947604                                   88.77
# 5      101.940818       0.991167                                   88.52
# 6      136.140257       0.993539                                   88.29
# 7       32.865802       0.980880                                   77.88
# 8       33.563861       0.977177                                   70.41
# 9       25.403433       0.908522                                   51.14
# 10       2.937331       0.931382                                   43.64
# 11      12.068378       0.916871                                   41.47
# 12       3.511335       0.937964                                   39.80
# 13       3.092184       0.902012                                   38.05
# 14       3.347207       0.930512                                   38.56
# 15       3.101836       0.902625                                   37.12
# 16       3.685022       0.930759                                   36.62
# 17       3.036957       0.882375                                   35.28
# 18       3.006012       0.877682                                   33.90
# 19       5.694112       0.913124                                   33.18
# 20       3.122534       0.869289                                   30.72
# 21       4.688133       0.904501                                   31.26
# 22       3.222602       0.870186                                   29.76
# 23       3.313685       0.875291                                   28.92
# 24       9.536773       0.915722                                   28.37
# 25       6.406079       0.912023                                   27.87
# 26       4.011359       0.883434                                   27.07
# 27      10.561352       0.909611                                   26.31
# 28       6.184292       0.869586                                   17.35
# 29       6.922310       0.869870                                   16.83
# 30       6.076979       0.894239                                   15.65
# 31      18.395722       0.869676                                    8.52
#
#     Presence/Absence
# 0            Present
# 1            Present
# 2            Present
# 3            Present
# 4            Present
# 5            Present
# 6            Present
# 7            Present
# 8            Present
# 9             Absent
# 10            Absent
# 11            Absent
# 12            Absent
# 13            Absent
# 14            Absent
# 15            Absent
# 16            Absent
# 17            Absent
# 18            Absent
# 19            Absent
# 20            Absent
# 21            Absent
# 22            Absent
# 23            Absent
# 24            Absent
# 25            Absent
# 26            Absent
# 27            Absent
# 28            Absent
# 29            Absent
# 30            Absent
# 31            Absent
#
# [32 rows x 21 columns]

# %%
ground_truth_abd = {
"Listeria monocytogenes": 12.0,
"Pseudomonas aeruginosa": 12.0,
"Bacillus spizizenii": 12.0,
"Escherichia coli": 12.0,
"Salmonella enterica": 12.0,
"Limosilactobacillus fermentum": 12.0,
"Enterococcus faecalis": 12.0,
"Staphylococcus aureus": 12.0,
"Saccharomyces cerevisiae": 2.0,
"Cryptococcus neoformans": 2.0,
}

# %%
ground_truth_set = set(ground_truth_abd.keys())

# %%
positive_calls = set(result_df[result_df['Presence/Absence'] == 'Present']['Species'].values)

# %%
len(ground_truth_set.intersection(positive_calls))
# Out:
# 8

# %%
ground_truth_set - positive_calls
# Out:
# {'Cryptococcus neoformans', 'Saccharomyces cerevisiae'}

# %%
result_df[result_df['Species'].isin(list(positive_calls - ground_truth_set))]
# Out:
#    Taxonomy ID Assembly Accession ID         Source Database  \
# 7          623       GCF_000006925.2  SOURCE_DATABASE_REFSEQ
#
#    Is Representative   Assembly Level           Organism of Assembly Strain  \
# 7               True  Complete Genome  Shigella flexneri 2a str. 301    301
#
#    Total Length  Downloaded            Species  ...  Secondary Expected  \
# 7     4828820.0        True  Shigella flexneri  ...                 1.0
#
#    Secondary Score  Secondary Depth  Primary Breadth  Primary Expected  \
# 7         0.889687       114.269365          0.78634               1.0
#
#    Primary Score  Primary Depth  Consensus ANI  \
# 7        0.78634      32.865802        0.98088
#
#    Combined PS and ANI (Sqrt(ANI)xPSx100)  Presence/Absence
# 7                                   77.88           Present
#
# [1 rows x 21 columns]

# %%
result_df[result_df['Species'].isin(list(ground_truth_set - positive_calls))]
# Out:
# Empty DataFrame
# Columns: [Taxonomy ID, Assembly Accession ID, Source Database, Is Representative, Assembly Level, Organism of Assembly, Strain, Total Length, Downloaded, Species, Secondary Breadth, Secondary Expected, Secondary Score, Secondary Depth, Primary Breadth, Primary Expected, Primary Score, Primary Depth, Consensus ANI, Combined PS and ANI (Sqrt(ANI)xPSx100), Presence/Absence]
# Index: []
#
# [0 rows x 21 columns]

# %% [markdown]
# # Argument Parser

# %%
parser = argparse.ArgumentParser(description="Universal Taxonomic Classification Verifier.")

parser.add_argument("-c", "--classification", type=pathlib.Path, required=True, help="Path to the Taxonomic Classification Report. Accepting csv/tsv file format, other text formats are treated as tsv.")
parser.add_argument("-i", "--fastq", type=pathlib.Path, required=True, help="Path to the first fastq file.")
parser.add_argument("-I", "--fastq2", type=pathlib.Path, required=False, help="Path to the second fastq file for paired-end reads.")
parser.add_argument("-m", "--mode", type=str, required=False, choices=['ont', 'illumina'], help="Modes for different sequencing platforms [ont, illumina]. Default:[ont]",  default='ont')
parser.add_argument("-o", "--output", type=pathlib.Path, required=True, help="Path to the output directory.")
parser.add_argument("-t", "--taxid-idx", type=int, required=False, help="The column index (0-based) of the taxids. Default:[0]", default=0)
parser.add_argument("-a", "--abundance-idx", type=int, required=False, help="The column index (0-based) of the abundance. Default:[None]")
parser.add_argument("--min-abundance", type=float, required=False, help="Minimum abundance (0-1) for pre-filtering, exclude taxa below the threshold.", default=0)
parser.add_argument("--min-mapq", type=int, required=False, help="Minimum MAPQ for primary alignments. Default:[20]", default=20)
parser.add_argument("--min-covscore", type=float, required=False, help="Minimum Coverage Score for supplementary alignments. Default:[0.7]", default=0.7)
parser.add_argument("--threads", type=int, required=False, help="Number of threads for Multi-threading. Default:[1]", default=1)
parser.add_argument("--include-mag", action='store_true', required=False, help="Include metagenomic assemble genomes. Default:[False]")
parser.set_defaults(include_mag=False)
parser.add_argument("--subspecies", action='store_true', required=False, help="Verify taxonomic classification at subspecies rank. Default:[False]")
parser.set_defaults(subspecies=False)

# %%
args = parser.parse_args(['-c', '/home/Users/ns58/emu40/Sim-Output/Large-uniform-8-0/Mob-combined-async/Mob-combined-async_rel-abundance.tsv',
                          '-i', '/home/Users/ns58/emu40/Sim-Data/Samples/Large_30species_rs3_startx10._ONT_8_0.fastq',
                          '-o', '../test',
                          '-t', str(0),
                          '--threads', str(40),
                          '--subspecies'])

# %%
print(' '.join(['-c', '/home/Users/ns58/emu40/Sim-Output/Large-uniform-8-0/Mob-combined-async/Mob-combined-async_rel-abundance.tsv',
                          '-i', '/home/Users/ns58/emu40/Sim-Data/Samples/Large_30species_rs3_startx10._ONT_8_0.fastq',
                          '-o', '../test',
                          '-t', str(0),
                          '--threads', str(40),
                          '--subspecies']))
# Out:
# -c /home/Users/ns58/emu40/Sim-Output/Large-uniform-8-0/Mob-combined-async/Mob-combined-async_rel-abundance.tsv -i /home/Users/ns58/emu40/Sim-Data/Samples/Large_30species_rs3_startx10._ONT_8_0.fastq -o ../test -t 0 --threads 40 --subspecies

# %%
input_tsv = args.classification
input_fastq = args.fastq
input_fastq2 = args.fastq2
mode = args.mode
working_directory = args.output

taxid_col_idx = args.taxid_idx
abundance_col_idx = args.abundance_idx
min_abundance = args.min_abundance
min_mapq = args.min_mapq
min_coverage_score = args.min_covscore
threads = args.threads

if args.include_mag:
    mag_flag = 'all'
else:
    mag_flag = 'exclude'
    
call_subspecies = args.subspecies

sep = '\t'
if str(input_file)[-3:] == 'csv':
    sep = ','

# %% [markdown]
# # Run

# %%
ncbi_taxa_db = NCBITaxa()

# %%
if not os.path.exists(working_directory):
    os.mkdir(working_directory)

# %%
input_df, min_abundance = parsing_input_f(input_file, sep, input_tsv, taxid_col_idx, abundance_col_idx, min_abundance)
# make valid_kingdom a variable?
valid_taxids = filter_input_df(input_df, min_abundance, ncbi_taxa_db, valid_kingdom={2, 4751, 2157, 10239}, ret_subspecies=call_subspecies)
# Out:
# unassigned is not a valid taxid.

# %%
# can be parallelized
reference_metadata = prepare_reference_genomes(valid_taxids, working_directory, ncbi_taxa_db, mag_flag=mag_flag)
# Out:
# 1246       	 GCF_007954605.1 	 Leuconostoc lactis             	 CBA3625    	 Complete Genome
# 173262     	 Genome Not Found.
# 927083     	 GCF_000737325.1 	 Sandaracinus amylolyticus      	 DSM 5366.. 	 Complete Genome
# 63363      	 GCF_000008625.1 	 Aquifex aeolicus VF5           	 VF5        	 Complete Genome
# 658062     	 GCF_000014005.1 	 Candidatus Koribacter versat.. 	 Ellin345   	 Complete Genome
# 1293412    	 GCF_006542355.1 	 Swingsia samuiensis            	 AH83       	 Complete Genome
# 2203724    	 GCF_004102045.2 	 Oenococcus sicerae             	 UCMA1522.. 	 Complete Genome
# 664643     	 GCF_024347035.1 	 Vibrio plantisponsor           	 CECT 758.. 	 Complete Genome
# 623        	 GCF_000006925.2 	 Shigella flexneri 2a str. 30.. 	 301        	 Complete Genome
# 154981     	 GCF_025137635.1 	 Aliiroseovarius crassostreae   	 S044       	 Complete Genome
# 2305508    	 GCF_003576455.2 	 Mucilaginibacter celer         	 HYN0043    	 Complete Genome
# 436        	 GCF_014843995.1 	 Novacetimonas hansenii         	 C110       	 Complete Genome
# 136241     	 GCF_000238995.1 	 Mycoplasma haemocanis str. I.. 	 Illinois   	 Complete Genome
# 380        	 GCF_003177055.1 	 Sinorhizobium fredii CCBAU 2.. 	 CCBAU 25.. 	 Complete Genome
# 445709     	 GCF_001017775.3 	 Pandoraea thiooxydans          	 DSM 2532.. 	 Complete Genome
# 413403     	 GCF_024347075.1 	 Vibrio rarus                   	 LMG 2367.. 	 Complete Genome
# 1851148    	 GCF_001999965.1 	 Limihaloglobus sulfuriphilus   	 SM-Chi-D.. 	 Complete Genome
# 28028      	 GCF_001941465.1 	 Corynebacterium flavescens     	 OJ8        	 Complete Genome
# 1197717    	 GCF_001701045.1 	 Cloacibacillus porcorum        	 CL-84 (T.. 	 Complete Genome
# 507626     	 GCF_001545155.1 	 Halomonas chromatireducens     	 AGD 8-3    	 Complete Genome
# 1389020    	 GCF_021442325.1 	 Agromyces marinus              	 DSM 2615.. 	 Complete Genome
# 190148     	 GCF_001693515.2 	 Bradyrhizobium paxllaeri       	 LMTR 21    	 Complete Genome
# 1761016    	 GCF_003368325.1 	 Paraburkholderia caffeinilyt.. 	 CF1        	 Complete Genome
# 392416     	 GCF_001951175.1 	 Companilactobacillus crustor.. 	 MN047      	 Complete Genome
# 2712892    	 GCF_013363675.1 	 Streptomyces sp. CAI-24        	 CAI-24     	 Contig
# 67258      	 GCF_002804165.1 	 Streptomyces cavourensis       	 1AS2a      	 Complete Genome
# 1169747    	 GCF_013363475.1 	 Streptomyces sp. KAI-26        	 KAI-26     	 Contig
# 2838874    	 GCF_018619515.1 	 Streptomyces sp. CYG21         	 CYG21      	 Contig
# 2838873    	 GCF_018619535.1 	 Streptomyces sp. CYG20         	 CYG20      	 Contig
# 945844     	 GCF_003143515.1 	 Massilia oculi                 	 CCUG 434.. 	 Complete Genome
# 1815583    	 GCF_014297595.1 	 Neisseria musculi              	 NW831      	 Complete Genome
# 2558283    	 GCF_004569405.1 	 Neisseria sp. WF04             	 WF04       	 Contig
# 577        	 GCF_012029655.1 	 Raoultella terrigena           	 JH01       	 Complete Genome
# 336203     	 GCF_015074805.1 	 Sphingobium fuliginis          	 KK22       	 Complete Genome
# 2878542    	 GCF_024611135.1 	 Sphingobium sp. CFD-2          	 CFD-2      	 Complete Genome
# 2940617    	 GCF_024810075.1 	 Raoultella sp. BIGb0132        	 BIGb0132   	 Contig
# 46354      	 GCF_000147695.2 	 Thermoanaerobacter wiegelii .. 	 Rt8.B1     	 Complete Genome
# 1516       	 GCF_900102395.1 	 Thermoanaerobacter thermohyd.. 	 DSM 569    	 Scaffold
# 1686286    	 GCF_006547305.1 	 Corynebacterium phoceense      	 272        	 Contig
# 2358       	 GCF_000266945.1 	 Desulfomonile tiedjei DSM 67.. 	 DSM 6799   	 Complete Genome
# 562        	 GCF_000008865.2 	 Escherichia coli O157:H7 str.. 	 Sakai su.. 	 Complete Genome
# 2093857    	 GCF_005121165.3 	 Dysosmobacter welbionis        	 J115       	 Complete Genome
# 28901      	 GCF_000006945.2 	 Salmonella enterica subsp. e.. 	 LT2        	 Complete Genome
# 2733484    	 GCF_017868775.1 	 Halomonas sulfidoxydans        	 MCCC 1A1.. 	 Complete Genome
# 615        	 GCF_000783915.2 	 Serratia marcescens            	 FDAARGOS.. 	 Complete Genome
# 468058     	 GCF_003148845.1 	 Mucilaginibacter oryzae        	 DSM 1997.. 	 Scaffold
# 47229      	 GCF_001866515.1 	 Massilia timonae               	 NEU        	 Contig
# 2490855    	 GCF_030008055.1 	 Lachnoanaerobaculum gingival.. 	 SHL-2023.. 	 Complete Genome
# 121428     	 GCF_002288285.1 	 Sphingobium xenophagum         	 C1         	 Complete Genome
# 399        	 GCF_000731315.1 	 Neorhizobium galegae bv. ori.. 	 HAMBI 54.. 	 Complete Genome
# 2920428    	 GCF_024195285.1 	 Aurantimonas marianensis       	 LRZ36      	 Contig
# 384        	 GCF_001679785.1 	 Rhizobium leguminosarum        	 Vaf10      	 Complete Genome
# 1076926    	 GCF_021052325.1 	 Rhizobium laguerreae           	 WSM1455    	 Complete Genome
# 396        	 GCF_001664385.1 	 Rhizobium phaseoli             	 R650       	 Complete Genome
# 2726076    	 GCF_023701945.1 	 Rhizobium sp. CG5              	 CG5        	 Scaffold
# 3041166    	 GCF_950101795.1 	 Nocardioides sp. T2.26MG-1     	            	 Scaffold
# 287        	 GCF_000006765.1 	 Pseudomonas aeruginosa PAO1    	 PAO1       	 Complete Genome
# 317        	 GCF_018394375.1 	 Pseudomonas syringae           	 Susan213.. 	 Complete Genome
# 285080     	 GCF_012396155.1 	 Cellulomonas septica           	 ATCC BAA.. 	 Contig
# 3055039    	 GCF_030380805.1 	 Rhizobium sp. S163             	 S163       	 Scaffold
# 3021407    	 GCF_030182485.1 	 Rhizobium sp. CNPSo 3490       	 CNPSo 34.. 	 Contig
# 2919500    	 GCF_022760965.1 	 Acidovorax sp. W1-6            	 W1-6       	 Contig
# 2847975    	 GCF_025128055.1 	 Synechococcus sp. CS-1329      	 CS-1329    	 Contig
# 114707     	 Genome Not Found.
# 134537     	 GCF_000961515.1 	 Paraburkholderia fungorum      	 ATCC BAA.. 	 Complete Genome
# 244566     	 GCF_001708485.1 	 Pseudomonas lurida             	 L228       	 Complete Genome

# %%
downloaded_assemblies = reference_metadata[reference_metadata['Downloaded']]

# %%
seq2assembly_dict = get_seq2assembly_dict(working_directory, downloaded_assemblies)

# %%
reference_fasta = merge_reference_fasta(list(downloaded_assemblies['Assembly Accession ID']), working_directory)

# %%
# %%time
aligner_output = run_minimap2(input_fastq, reference_fasta, 'merged', working_directory, threads=threads)
sort_samfile('merged', aligner_output, working_directory, min_mapq=0, threads=threads)

# %%
# %%time
pool = Pool(processes=threads)
pool.starmap(samtools_calculate_coverage, zip(repeat(working_directory), [True, False]))
pool.close()
pool.join()
# Out:
# CPU times: user 26.2 ms, sys: 254 ms, total: 280 ms
# Wall time: 2min 18s

# %%
downloaded_assemblies = alignment_summary(downloaded_assemblies,
                                          working_directory,
                                          seq2assembly_dict,
                                          include_supp=True)

# %%
downloaded_assemblies = alignment_summary(downloaded_assemblies,
                                          working_directory,
                                          seq2assembly_dict,
                                          include_supp=False)

# %%
# %%time
consensus_record_dict = samtools_merged_consensus(working_directory, threads)
# Out:
# CPU times: user 1.03 s, sys: 392 ms, total: 1.43 s
# Wall time: 3min 31s

# %%
# %%time
downloaded_assemblies = ani_summary(downloaded_assemblies, consensus_record_dict, working_directory, threads)
# Out:
# CPU times: user 5.29 s, sys: 14.9 s, total: 20.2 s
# Wall time: 37.5 s

# %%
downloaded_assemblies = call_present_absent(downloaded_assemblies, min_coverage_score)

# %%
downloaded_assemblies.sort_values(['Primary Score'], ascending=False).to_csv(os.path.join(working_directory, 
                                                                                          'magnet_results.csv'), 
                                                                             index=False)

# %% [markdown]
# # Results

# %%
downloaded_assemblies[downloaded_assemblies['Presence/Absence'] == 'Present']
# Out:
#     Taxonomy ID Assembly Accession ID         Source Database  \
# 0          1246       GCF_007954605.1  SOURCE_DATABASE_REFSEQ
# 2        927083       GCF_000737325.1  SOURCE_DATABASE_REFSEQ
# 3         63363       GCF_000008625.1  SOURCE_DATABASE_REFSEQ
# 4        658062       GCF_000014005.1  SOURCE_DATABASE_REFSEQ
# 5       1293412       GCF_006542355.1  SOURCE_DATABASE_REFSEQ
# 6       2203724       GCF_004102045.2  SOURCE_DATABASE_REFSEQ
# 7        664643       GCF_024347035.1  SOURCE_DATABASE_REFSEQ
# 8           623       GCF_000006925.2  SOURCE_DATABASE_REFSEQ
# 9        154981       GCF_025137635.1  SOURCE_DATABASE_REFSEQ
# 10      2305508       GCF_003576455.2  SOURCE_DATABASE_REFSEQ
# 11          436       GCF_014843995.1  SOURCE_DATABASE_REFSEQ
# 12       136241       GCF_000238995.1  SOURCE_DATABASE_REFSEQ
# 13          380       GCF_003177055.1  SOURCE_DATABASE_REFSEQ
# 14       445709       GCF_001017775.3  SOURCE_DATABASE_REFSEQ
# 15       413403       GCF_024347075.1  SOURCE_DATABASE_REFSEQ
# 16      1851148       GCF_001999965.1  SOURCE_DATABASE_REFSEQ
# 17        28028       GCF_001941465.1  SOURCE_DATABASE_REFSEQ
# 18      1197717       GCF_001701045.1  SOURCE_DATABASE_REFSEQ
# 20      1389020       GCF_021442325.1  SOURCE_DATABASE_REFSEQ
# 21       190148       GCF_001693515.2  SOURCE_DATABASE_REFSEQ
# 22      1761016       GCF_003368325.1  SOURCE_DATABASE_REFSEQ
# 23       392416       GCF_001951175.1  SOURCE_DATABASE_REFSEQ
# 25        67258       GCF_002804165.1  SOURCE_DATABASE_REFSEQ
# 29       945844       GCF_003143515.1  SOURCE_DATABASE_REFSEQ
# 30      1815583       GCF_014297595.1  SOURCE_DATABASE_REFSEQ
# 32          577       GCF_012029655.1  SOURCE_DATABASE_REFSEQ
# 33       336203       GCF_015074805.1  SOURCE_DATABASE_REFSEQ
# 36        46354       GCF_000147695.2  SOURCE_DATABASE_REFSEQ
# 39         2358       GCF_000266945.1  SOURCE_DATABASE_REFSEQ
# 43      2733484       GCF_017868775.1  SOURCE_DATABASE_REFSEQ
#
#    Is Representative   Assembly Level  \
# 0               True  Complete Genome
# 2               True  Complete Genome
# 3               True  Complete Genome
# 4               True  Complete Genome
# 5               True  Complete Genome
# 6               True  Complete Genome
# 7               True  Complete Genome
# 8               True  Complete Genome
# 9               True  Complete Genome
# 10              True  Complete Genome
# 11              True  Complete Genome
# 12              True  Complete Genome
# 13              True  Complete Genome
# 14              True  Complete Genome
# 15              True  Complete Genome
# 16              True  Complete Genome
# 17              True  Complete Genome
# 18              True  Complete Genome
# 20              True  Complete Genome
# 21              True  Complete Genome
# 22              True  Complete Genome
# 23              True  Complete Genome
# 25              True  Complete Genome
# 29              True  Complete Genome
# 30              True  Complete Genome
# 32              True  Complete Genome
# 33              True  Complete Genome
# 36              True  Complete Genome
# 39              True  Complete Genome
# 43              True  Complete Genome
#
#                          Organism of Assembly        Strain  Total Length  \
# 0                          Leuconostoc lactis       CBA3625     1791608.0
# 2                   Sandaracinus amylolyticus     DSM 53668    10327335.0
# 3                        Aquifex aeolicus VF5           VF5     1590791.0
# 4   Candidatus Koribacter versatilis Ellin345      Ellin345     5650368.0
# 5                         Swingsia samuiensis          AH83     2193407.0
# 6                          Oenococcus sicerae     UCMA15228     1664394.0
# 7                        Vibrio plantisponsor     CECT 7581     4509247.0
# 8               Shigella flexneri 2a str. 301           301     4828820.0
# 9                Aliiroseovarius crassostreae          S044     3367659.0
# 10                     Mucilaginibacter celer       HYN0043     7149106.0
# 11                     Novacetimonas hansenii          C110     3549186.0
# 12        Mycoplasma haemocanis str. Illinois      Illinois      919992.0
# 13           Sinorhizobium fredii CCBAU 25509   CCBAU 25509     6810864.0
# 14                      Pandoraea thiooxydans     DSM 25325     4464186.0
# 15                               Vibrio rarus     LMG 23674     3877193.0
# 16               Limihaloglobus sulfuriphilus     SM-Chi-D1     3868357.0
# 17                 Corynebacterium flavescens           OJ8     2758653.0
# 18                    Cloacibacillus porcorum     CL-84 (T)     3585187.0
# 20                          Agromyces marinus     DSM 26151     3202016.0
# 21                   Bradyrhizobium paxllaeri       LMTR 21     8377719.0
# 22            Paraburkholderia caffeinilytica           CF1     8324638.0
# 23             Companilactobacillus crustorum         MN047     2316479.0
# 25                   Streptomyces cavourensis         1AS2a     7600475.0
# 29                             Massilia oculi    CCUG 43427     5844653.0
# 30                          Neisseria musculi         NW831     2933071.0
# 32                       Raoultella terrigena          JH01     5598454.0
# 33                      Sphingobium fuliginis          KK22     4984172.0
# 36         Thermoanaerobacter wiegelii Rt8.B1        Rt8.B1     2785056.0
# 39             Desulfomonile tiedjei DSM 6799      DSM 6799     6527027.0
# 43                    Halomonas sulfidoxydans  MCCC 1A11059     4491948.0
#
#     Downloaded                           Species  ...  Secondary Breadth  \
# 0         True                Leuconostoc lactis  ...           0.999951
# 2         True         Sandaracinus amylolyticus  ...           1.000000
# 3         True                  Aquifex aeolicus  ...           0.999932
# 4         True  Candidatus Koribacter versatilis  ...           0.999977
# 5         True               Swingsia samuiensis  ...           0.999929
# 6         True                Oenococcus sicerae  ...           0.999871
# 7         True              Vibrio plantisponsor  ...           0.999960
# 8         True                 Shigella flexneri  ...           0.999904
# 9         True      Aliiroseovarius crassostreae  ...           0.999794
# 10        True            Mucilaginibacter celer  ...           0.999760
# 11        True            Novacetimonas hansenii  ...           0.999419
# 12        True             Mycoplasma haemocanis  ...           0.999188
# 13        True              Sinorhizobium fredii  ...           0.999976
# 14        True             Pandoraea thiooxydans  ...           0.999933
# 15        True                      Vibrio rarus  ...           0.999865
# 16        True      Limihaloglobus sulfuriphilus  ...           0.999950
# 17        True        Corynebacterium flavescens  ...           0.999901
# 18        True           Cloacibacillus porcorum  ...           0.999960
# 20        True                 Agromyces marinus  ...           0.999974
# 21        True          Bradyrhizobium paxllaeri  ...           0.999984
# 22        True   Paraburkholderia caffeinilytica  ...           0.999977
# 23        True    Companilactobacillus crustorum  ...           0.999683
# 25        True          Streptomyces cavourensis  ...           0.999994
# 29        True                    Massilia oculi  ...           1.000000
# 30        True                 Neisseria musculi  ...           0.999963
# 32        True              Raoultella terrigena  ...           0.999997
# 33        True             Sphingobium fuliginis  ...           0.999919
# 36        True       Thermoanaerobacter wiegelii  ...           0.999947
# 39        True             Desulfomonile tiedjei  ...           0.999981
# 43        True           Halomonas sulfidoxydans  ...           0.999982
#
#     Secondary Expected  Secondary Score  Secondary Depth  Primary Breadth  \
# 0             1.000000         0.999951        99.860177         0.999951
# 2             1.000000         1.000000        49.606000         0.999992
# 3             1.000000         0.999932        49.586588         0.999932
# 4             1.000000         0.999977        98.981260         0.999977
# 5             1.000000         0.999929       100.964187         0.999929
# 6             1.000000         0.999871        49.581504         0.999871
# 7             1.000000         0.999960        50.684451         0.999960
# 8             1.000000         0.999904        22.716979         0.999904
# 9             1.000000         0.999794        19.906297         0.999794
# 10            1.000000         0.999760        19.861267         0.999760
# 11            0.999955         0.999464        10.000399         0.999419
# 12            1.000000         0.999188        19.812887         0.999188
# 13            1.000000         0.999976       103.333486         0.999976
# 14            1.000000         0.999933        19.914034         0.999933
# 15            1.000000         0.999865        20.375531         0.999865
# 16            1.000000         0.999950       100.264028         0.999950
# 17            1.000000         0.999901        50.766405         0.999901
# 18            1.000000         0.999960        99.919357         0.999943
# 20            1.000000         0.999974        99.276504         0.999974
# 21            1.000000         0.999984        50.402800         0.999984
# 22            1.000000         0.999977        20.064410         0.999488
# 23            0.999965         0.999719        10.241042         0.999683
# 25            1.000000         0.999994        49.725614         0.999983
# 29            1.000000         1.000000        99.814100         0.999962
# 30            1.000000         0.999963        50.761172         0.999963
# 32            1.000000         0.999997        99.720803         0.999997
# 33            1.000000         0.999919        50.386814         0.824513
# 36            1.000000         0.999947       101.209415         0.999947
# 39            1.000000         0.999981        20.117984         0.999980
# 43            1.000000         0.999982        49.732874         0.999982
#
#     Primary Expected  Primary Score  Primary Depth  \
# 0           1.000000       0.999951      98.808125
# 2           1.000000       0.999992      49.413092
# 3           1.000000       0.999932      49.447579
# 4           1.000000       0.999977      98.947459
# 5           1.000000       0.999929      99.078553
# 6           1.000000       0.999871      49.436986
# 7           1.000000       0.999960      49.405227
# 8           1.000000       0.999904      19.765296
# 9           1.000000       0.999794      19.789472
# 10          1.000000       0.999760      19.789550
# 11          0.999949       0.999470       9.888364
# 12          1.000000       0.999188      19.806581
# 13          1.000000       0.999976     100.712422
# 14          1.000000       0.999933      19.786825
# 15          1.000000       0.999865      19.762609
# 16          1.000000       0.999950      98.883759
# 17          1.000000       0.999901      48.833515
# 18          1.000000       0.999943      98.855180
# 20          1.000000       0.999974      98.883394
# 21          1.000000       0.999984      49.757890
# 22          1.000000       0.999488      19.822158
# 23          0.999950       0.999733       9.902845
# 25          1.000000       0.999983      47.023317
# 29          1.000000       0.999962      98.874955
# 30          1.000000       0.999963      48.780799
# 32          1.000000       0.999997      98.528117
# 33          1.000000       0.824513      33.643599
# 36          1.000000       0.999947      98.311759
# 39          1.000000       0.999980      19.713291
# 43          1.000000       0.999982      49.468670
#
#     Combined PS and ANI (Sqrt(ANI)xPSx100)  Presence/Absence
# 0                                    99.99           Present
# 2                                   100.00           Present
# 3                                    99.99           Present
# 4                                   100.00           Present
# 5                                    99.99           Present
# 6                                    99.99           Present
# 7                                   100.00           Present
# 8                                    99.95           Present
# 9                                    99.98           Present
# 10                                   99.98           Present
# 11                                   99.95           Present
# 12                                   99.92           Present
# 13                                   99.99           Present
# 14                                   99.99           Present
# 15                                   99.99           Present
# 16                                   99.99           Present
# 17                                   99.99           Present
# 18                                   99.99           Present
# 20                                  100.00           Present
# 21                                   99.99           Present
# 22                                   99.95           Present
# 23                                   99.97           Present
# 25                                  100.00           Present
# 29                                  100.00           Present
# 30                                  100.00           Present
# 32                                  100.00           Present
# 33                                   82.38           Present
# 36                                   99.99           Present
# 39                                  100.00           Present
# 43                                  100.00           Present
#
# [30 rows x 21 columns]

# %%
ground_truth_abd = {
"Leuconostoc lactis": 10.0,
"Cloacibacillus porcorum": 10.0,
"Limihaloglobus sulfuriphilus": 10.0,
"Sinorhizobium fredii": 10.0,
"Massilia oculi": 10.0,
"Raoultella terrigena": 10.0,
"Agromyces marinus": 10.0,
"Thermoanaerobacter wiegelii": 10.0,
"Candidatus Koribacter versatilis": 10.0,
"Swingsia samuiensis": 10.0,
"Sphingobium fuliginis": 5.0,
"Aquifex aeolicus": 5.0,
"Corynebacterium flavescens": 5.0,
"Oenococcus sicerae": 5.0,
"Vibrio plantisponsor": 5.0,
"Bradyrhizobium paxllaeri": 5.0,
"Sandaracinus amylolyticus": 5.0,
"Halomonas sulfidoxydans": 5.0,
"Neisseria musculi": 5.0,
"Streptomyces cavourensis": 5.0,
"Desulfomonile tiedjei": 2.0,
"Mycoplasma haemocanis": 2.0,
"Paraburkholderia caffeinilytica": 2.0,
"Shigella flexneri": 2.0,
"Vibrio rarus": 2.0,
"Pandoraea thiooxydans": 2.0,
"Aliiroseovarius crassostreae": 2.0,
"Mucilaginibacter celer": 2.0,
"Novacetimonas hansenii": 1.0,
"Companilactobacillus crustorum": 1.0,
}

# %%
ground_truth_set = set(ground_truth_abd.keys())

# %%
positive_calls = set(downloaded_assemblies[downloaded_assemblies['Presence/Absence'] == 'Present']['Species'].values)

# %%
#positive_calls = set(downloaded_assemblies[downloaded_assemblies['Combined CS2 and ANI (Sqrt(ANI)xCS2x100)'] >= 97]['Species'].values)

# %%
len(positive_calls)
# Out:
# 30

# %%
len(ground_truth_set.intersection(positive_calls))
# Out:
# 30

# %%
len(ground_truth_set - positive_calls)
# Out:
# 0

# %%
len(positive_calls - ground_truth_set)
# Out:
# 0

# %%
downloaded_assemblies[downloaded_assemblies['Species'].isin(list(positive_calls - ground_truth_set))]
# Out:
# Empty DataFrame
# Columns: [Taxonomy ID, Assembly Accession ID, Source Database, Is Representative, Assembly Level, Organism of Assembly, Strain, Total Length, Downloaded, Species, Consensus ANI, Secondary Breadth, Secondary Expected, Secondary Score, Secondary Depth, Primary Breadth, Primary Expected, Primary Score, Primary Depth, Combined PS and ANI (Sqrt(ANI)xPSx100), Presence/Absence]
# Index: []
#
# [0 rows x 21 columns]
