# %%
import os
import subprocess
from collections import defaultdict
import math
import pandas as pd
from Bio import SeqIO

# %%
def cal_ani(assembly_id, output_directory, consensus_record_dict, ignore_del=False, del_count_as_match=False):
    reference_fasta = os.path.join(reference_genome_path, f'{assembly_id}.fasta')

    with open(reference_fasta, "r") as handle:
        total_count = 0
        matched_count = 0

        for record in SeqIO.parse(handle, "fasta"):
            if record.id in consensus_record_dict:
                for idx, base in enumerate(record.seq):
                    if consensus_record_dict[record.id][idx] != 'N':
                        if consensus_record_dict[record.id][idx] == '*' and ignore_del:
                            continue
                        elif consensus_record_dict[record.id][idx] == '*':
                            total_count += 1
                            if del_count_as_match:
                                matched_count += 1
                        else:
                            total_count += 1
                            if consensus_record_dict[record.id][idx] == base:
                                matched_count += 1
                            
            else:
                print("No alignment found:", record.id, record.description)
                    
    if total_count != 0:
        return matched_count/total_count
    else:
        return 0

# %%
def samtools_merged_consensus(output_directory, threads):
    merged_bam = os.path.join(output_directory, 'bam_files', 'merged.sorted.bam')
    subprocess.run(['samtools', 'consensus', 
                    '--show-ins', 'no', 
                    '--show-del', 'yes', 
                    '-a',
                    '--mode', "simple",
                    '--threads', str(threads),
                    merged_bam, 
                    '-o', os.path.join(output_directory, 'merged_consensus.fasta')],
                  check=True)
    
    consensus_record_dict = SeqIO.to_dict(SeqIO.parse(os.path.join(output_directory, 'merged_consensus.fasta'), "fasta"))
    return consensus_record_dict

# %%
threads=20

# %%
output_directory = "/home/Users/yl181/seqscreen_nano/test"
reference_genome_path = os.path.join(output_directory, 'reference_genomes')

# %%
re_alignment_metadata = pd.read_csv(os.path.join(output_directory, 'alignment.csv'))

# %%
re_alignment_metadata
# Out:
#     Taxonomy ID Assembly Accession ID  \
# 0         96241       GCF_006094475.1
# 1           287       GCF_000006765.1
# 2          5207       GCA_022832995.1
# 3          1639       GCF_000196035.1
# 4         28901       GCF_000006945.2
# 5          1280       GCF_000013425.1
# 6          4932       GCF_000146045.2
# 7          1351       GCF_001598635.1
# 8          1613       GCF_022819245.1
# 9           562       GCF_000008865.2
# 10          623       GCF_000006925.2
# 11         1642       GCF_009648575.1
# 12         1643       GCF_900187315.1
# 13         1423       GCF_000009045.1
# 14         1638       GCF_000763515.1
# 15         1392       GCF_000008445.1
# 16          573       GCF_000240185.1
# 17         1590       GCF_003269405.1
# 18         1352       GCF_009734005.1
# 19          294       GCF_000730425.1
# 20       176275       GCA_014607475.1
#
#                                       Source Database  Is Representative  \
# 0                                         NCBI RefSeq               True
# 1                            PathoGenesis Corporation               True
# 2                                     Broad Institute              False
# 3                                 European Consortium               True
# 4      Washington University Genome Sequencing Center               True
# 5       University of Oklahoma Health Sciences Center               True
# 6                       Saccharomyces Genome Database               True
# 7                                         NCBI RefSeq              False
# 8                                         NCBI RefSeq               True
# 9                                                GIRC               True
# 10                   Microbial Genome Center of ChMPH               True
# 11                                        NCBI RefSeq               True
# 12                                        NCBI RefSeq               True
# 13                                               BSNR               True
# 14                                        NCBI RefSeq               True
# 15                                        NCBI RefSeq               True
# 16   Bioinformatics & Microbial Genomics, State Ke...               True
# 17                                        NCBI RefSeq               True
# 18                                        NCBI RefSeq               True
# 19                                        NCBI RefSeq              False
# 20                                                NaN              False
#
#      Assembly Level                               Organism of Assembly  \
# 0   Complete Genome  Bacillus subtilis subsp. spizizenii ATCC 6633 ...
# 1   Complete Genome                        Pseudomonas aeruginosa PAO1
# 2   Complete Genome                            Cryptococcus neoformans
# 3   Complete Genome                       Listeria monocytogenes EGD-e
# 4   Complete Genome  Salmonella enterica subsp. enterica serovar Ty...
# 5   Complete Genome      Staphylococcus aureus subsp. aureus NCTC 8325
# 6   Complete Genome                     Saccharomyces cerevisiae S288C
# 7   Complete Genome                              Enterococcus faecalis
# 8   Complete Genome                      Limosilactobacillus fermentum
# 9   Complete Genome                Escherichia coli O157:H7 str. Sakai
# 10  Complete Genome                      Shigella flexneri 2a str. 301
# 11  Complete Genome                                   Listeria innocua
# 12  Complete Genome                                Listeria welshimeri
# 13  Complete Genome         Bacillus subtilis subsp. subtilis str. 168
# 14  Complete Genome                  Listeria ivanovii subsp. ivanovii
# 15  Complete Genome            Bacillus anthracis str. 'Ames Ancestor'
# 16  Complete Genome    Klebsiella pneumoniae subsp. pneumoniae HS11286
# 17  Complete Genome                      Lactiplantibacillus plantarum
# 18  Complete Genome                               Enterococcus faecium
# 19  Complete Genome                            Pseudomonas fluorescens
# 20  Complete Genome                                 Beauveria bassiana
#
#                         Strain  Downloaded                        Species  \
# 0                    ATCC 6633        True            Bacillus spizizenii
# 1                         PAO1        True         Pseudomonas aeruginosa
# 2                         VNII        True        Cryptococcus neoformans
# 3                        EGD-e        True         Listeria monocytogenes
# 4                          LT2        True            Salmonella enterica
# 5                    NCTC 8325        True          Staphylococcus aureus
# 6                        S288C        True       Saccharomyces cerevisiae
# 7                         LD33        True          Enterococcus faecalis
# 8                      SCB0035        True  Limosilactobacillus fermentum
# 9   Sakai substr. RIMD 0509952        True               Escherichia coli
# 10                         301        True              Shigella flexneri
# 11                 CFSAN044836        True               Listeria innocua
# 12                   NCTC11857        True            Listeria welshimeri
# 13                         168        True              Bacillus subtilis
# 14                   WSLC 3010        True              Listeria ivanovii
# 15        Ames Ancestor; A2084        True             Bacillus anthracis
# 16                     HS11286        True          Klebsiella pneumoniae
# 17                       SK151        True  Lactiplantibacillus plantarum
# 18                       SRR24        True           Enterococcus faecium
# 19                         UK4        True        Pseudomonas fluorescens
# 20                         HN6        True             Beauveria bassiana
#
#     Breadth Coverage  Expected Coverage  Coverage Score  Depth Coverage  \
# 0           1.000000           1.000000        1.000000       28.817028
# 1           0.969225           0.999858        0.969363        9.133267
# 2           0.423306           0.441691        0.958376        1.376761
# 3           0.943656           1.000000        0.943656       29.246736
# 4           0.929463           1.000000        0.929463       20.590929
# 5           0.923386           1.000000        0.923386       27.298416
# 6           0.619563           0.678052        0.913740        1.829052
# 7           0.894675           1.000000        0.894675       26.467055
# 8           0.863003           1.000000        0.863003       34.935137
# 9           0.783966           1.000000        0.783966       20.741795
# 10          0.824164           1.000000        0.824164       21.251002
# 11          0.909038           1.000000        0.909038       27.840245
# 12          0.885401           1.000000        0.885401       27.171881
# 13          0.870655           1.000000        0.870655       27.710430
# 14          0.844076           1.000000        0.844076       25.379467
# 15          0.058483           0.545025        0.107303       13.463243
# 16          0.551682           0.999930        0.551720       17.326926
# 17          0.026909           0.392528        0.068553       18.516941
# 18          0.184407           0.884029        0.208599       11.678256
# 19          0.432934           0.923317        0.468890        5.930036
# 20          0.000145           0.000288        0.503848        1.984978
#
#          BC2       EC2       CS2        DC2
# 0   1.000000  1.000000  1.000000  28.435225
# 1   0.969233  0.999831  0.969397   8.957587
# 2   0.423340  0.441638  0.958569   1.376418
# 3   0.932411  1.000000  0.932411  26.446730
# 4   0.925799  0.999995  0.925804  13.176773
# 5   0.923337  1.000000  0.923337  26.221774
# 6   0.619487  0.677297  0.914646   1.825484
# 7   0.894216  1.000000  0.894216  25.709091
# 8   0.863029  1.000000  0.863029  34.607012
# 9   0.651192  0.990895  0.657175   7.212012
# 10  0.645942  0.986536  0.654758   6.664883
# 11  0.197003  0.858570  0.229455   9.922948
# 12  0.028555  0.216781  0.131724   8.551594
# 13  0.001802  0.017990  0.100147  10.074259
# 14  0.015927  0.185539  0.085844  12.875809
# 15  0.000000  0.000000  0.000000   0.000000
# 16  0.000000  0.000000  0.000000   0.000000
# 17  0.000000  0.000000  0.000000   0.000000
# 18  0.000000  0.000000  0.000000   0.000000
# 19  0.000000  0.000000  0.000000   0.000000
# 20  0.000000  0.000000  0.000000   0.000000

# %%
merged_bam = os.path.join(output_directory, 'bam_files', 'merged.sorted.bam')
subprocess.run(['samtools', 'consensus', 
                '--show-ins', 'no', 
                '--show-del', 'yes', 
                '-a',
                '--mode', "simple",
                '--threads', str(threads),
                merged_bam, 
                '-o', os.path.join(output_directory, 'simple_merged_consensus.fasta')],
              check=True)
# Out:
# CompletedProcess(args=['samtools', 'consensus', '--show-ins', 'no', '--show-del', 'yes', '-a', '--mode', 'simple', '--threads', '20', '/home/Users/yl181/seqscreen_nano/test/bam_files/merged.sorted.bam', '-o', '/home/Users/yl181/seqscreen_nano/test/simple_merged_consensus.fasta'], returncode=0)

# %%
consensus_record_dict = SeqIO.to_dict(SeqIO.parse(os.path.join(output_directory, 'simple_merged_consensus.fasta'), "fasta"))

# %%
ani_list = []
for idx, row in re_alignment_metadata.iterrows():
    if row['CS2'] != 0:
        assembly_id = row['Assembly Accession ID']
        ani_list.append(cal_ani(assembly_id))
    else:
        ani_list.append(0)

# %%
re_alignment_metadata['Simple Consensus ANI'] = ani_list

# %%
#re_alignment_metadata.sort_values(['Coverage Score'], ascending=False).to_csv(os.path.join(output_directory, 're-alignment.csv'), index=False)

# %%
ani_list = []
for idx, row in re_alignment_metadata.iterrows():
    if row['CS2'] != 0:
        assembly_id = row['Assembly Accession ID']
        ani_list.append(cal_ani(assembly_id, output_directory, consensus_record_dict, ignore_del=True))
    else:
        ani_list.append(0)
# Out:
# No alignment found: NC_002127.1 NC_002127.1 Escherichia coli O157:H7 str. Sakai plasmid pOSAK1, complete sequence

# %%
re_alignment_metadata['Simple Consensus ANI (Ignore DEL)'] = ani_list

# %%
ani_list = []
for idx, row in re_alignment_metadata.iterrows():
    if row['CS2'] != 0:
        assembly_id = row['Assembly Accession ID']
        ani_list.append(cal_ani(assembly_id, del_count_as_match=True))
    else:
        ani_list.append(0)

# %%
re_alignment_metadata['Simple Consensus ANI (DEL count as match)'] = ani_list

# %%
re_alignment_metadata.sort_values(['CS2'], ascending=False)[['Species', 'CS2', 'Consensus ANI', 'Simple Consensus ANI', 'Simple Consensus ANI (Ignore DEL)', 'Simple Consensus ANI (DEL count as match)']]

# %%
re_alignment_metadata
# Out:
#     Taxonomy ID Assembly Accession ID  \
# 0         96241       GCF_006094475.1
# 1           287       GCF_000006765.1
# 2          5207       GCA_022832995.1
# 3          1639       GCF_000196035.1
# 4         28901       GCF_000006945.2
# 5          1280       GCF_000013425.1
# 6          4932       GCF_000146045.2
# 7          1351       GCF_001598635.1
# 8          1613       GCF_022819245.1
# 9           562       GCF_000008865.2
# 10          623       GCF_000006925.2
# 11         1642       GCF_009648575.1
# 12         1643       GCF_900187315.1
# 13         1423       GCF_000009045.1
# 14         1638       GCF_000763515.1
# 15         1392       GCF_000008445.1
# 16          573       GCF_000240185.1
# 17         1590       GCF_003269405.1
# 18         1352       GCF_009734005.1
# 19          294       GCF_000730425.1
# 20       176275       GCA_014607475.1
#
#                                       Source Database  Is Representative  \
# 0                                         NCBI RefSeq               True
# 1                            PathoGenesis Corporation               True
# 2                                     Broad Institute              False
# 3                                 European Consortium               True
# 4      Washington University Genome Sequencing Center               True
# 5       University of Oklahoma Health Sciences Center               True
# 6                       Saccharomyces Genome Database               True
# 7                                         NCBI RefSeq              False
# 8                                         NCBI RefSeq               True
# 9                                                GIRC               True
# 10                   Microbial Genome Center of ChMPH               True
# 11                                        NCBI RefSeq               True
# 12                                        NCBI RefSeq               True
# 13                                               BSNR               True
# 14                                        NCBI RefSeq               True
# 15                                        NCBI RefSeq               True
# 16   Bioinformatics & Microbial Genomics, State Ke...               True
# 17                                        NCBI RefSeq               True
# 18                                        NCBI RefSeq               True
# 19                                        NCBI RefSeq              False
# 20                                                NaN              False
#
#      Assembly Level                               Organism of Assembly  \
# 0   Complete Genome  Bacillus subtilis subsp. spizizenii ATCC 6633 ...
# 1   Complete Genome                        Pseudomonas aeruginosa PAO1
# 2   Complete Genome                            Cryptococcus neoformans
# 3   Complete Genome                       Listeria monocytogenes EGD-e
# 4   Complete Genome  Salmonella enterica subsp. enterica serovar Ty...
# 5   Complete Genome      Staphylococcus aureus subsp. aureus NCTC 8325
# 6   Complete Genome                     Saccharomyces cerevisiae S288C
# 7   Complete Genome                              Enterococcus faecalis
# 8   Complete Genome                      Limosilactobacillus fermentum
# 9   Complete Genome                Escherichia coli O157:H7 str. Sakai
# 10  Complete Genome                      Shigella flexneri 2a str. 301
# 11  Complete Genome                                   Listeria innocua
# 12  Complete Genome                                Listeria welshimeri
# 13  Complete Genome         Bacillus subtilis subsp. subtilis str. 168
# 14  Complete Genome                  Listeria ivanovii subsp. ivanovii
# 15  Complete Genome            Bacillus anthracis str. 'Ames Ancestor'
# 16  Complete Genome    Klebsiella pneumoniae subsp. pneumoniae HS11286
# 17  Complete Genome                      Lactiplantibacillus plantarum
# 18  Complete Genome                               Enterococcus faecium
# 19  Complete Genome                            Pseudomonas fluorescens
# 20  Complete Genome                                 Beauveria bassiana
#
#                         Strain  Downloaded                        Species  \
# 0                    ATCC 6633        True            Bacillus spizizenii
# 1                         PAO1        True         Pseudomonas aeruginosa
# 2                         VNII        True        Cryptococcus neoformans
# 3                        EGD-e        True         Listeria monocytogenes
# 4                          LT2        True            Salmonella enterica
# 5                    NCTC 8325        True          Staphylococcus aureus
# 6                        S288C        True       Saccharomyces cerevisiae
# 7                         LD33        True          Enterococcus faecalis
# 8                      SCB0035        True  Limosilactobacillus fermentum
# 9   Sakai substr. RIMD 0509952        True               Escherichia coli
# 10                         301        True              Shigella flexneri
# 11                 CFSAN044836        True               Listeria innocua
# 12                   NCTC11857        True            Listeria welshimeri
# 13                         168        True              Bacillus subtilis
# 14                   WSLC 3010        True              Listeria ivanovii
# 15        Ames Ancestor; A2084        True             Bacillus anthracis
# 16                     HS11286        True          Klebsiella pneumoniae
# 17                       SK151        True  Lactiplantibacillus plantarum
# 18                       SRR24        True           Enterococcus faecium
# 19                         UK4        True        Pseudomonas fluorescens
# 20                         HN6        True             Beauveria bassiana
#
#     Breadth Coverage  Expected Coverage  Coverage Score  Depth Coverage  \
# 0           1.000000           1.000000        1.000000       28.817028
# 1           0.969225           0.999858        0.969363        9.133267
# 2           0.423306           0.441691        0.958376        1.376761
# 3           0.943656           1.000000        0.943656       29.246736
# 4           0.929463           1.000000        0.929463       20.590929
# 5           0.923386           1.000000        0.923386       27.298416
# 6           0.619563           0.678052        0.913740        1.829052
# 7           0.894675           1.000000        0.894675       26.467055
# 8           0.863003           1.000000        0.863003       34.935137
# 9           0.783966           1.000000        0.783966       20.741795
# 10          0.824164           1.000000        0.824164       21.251002
# 11          0.909038           1.000000        0.909038       27.840245
# 12          0.885401           1.000000        0.885401       27.171881
# 13          0.870655           1.000000        0.870655       27.710430
# 14          0.844076           1.000000        0.844076       25.379467
# 15          0.058483           0.545025        0.107303       13.463243
# 16          0.551682           0.999930        0.551720       17.326926
# 17          0.026909           0.392528        0.068553       18.516941
# 18          0.184407           0.884029        0.208599       11.678256
# 19          0.432934           0.923317        0.468890        5.930036
# 20          0.000145           0.000288        0.503848        1.984978
#
#          BC2       EC2       CS2        DC2  Simple Consensus ANI (Ignore DEL)
# 0   1.000000  1.000000  1.000000  28.435225                           0.999993
# 1   0.969233  0.999831  0.969397   8.957587                           0.995790
# 2   0.423340  0.441638  0.958569   1.376418                           0.864170
# 3   0.932411  1.000000  0.932411  26.446730                           0.962211
# 4   0.925799  0.999995  0.925804  13.176773                           0.992369
# 5   0.923337  1.000000  0.923337  26.221774                           0.993944
# 6   0.619487  0.677297  0.914646   1.825484                           0.976131
# 7   0.894216  1.000000  0.894216  25.709091                           0.993251
# 8   0.863029  1.000000  0.863029  34.607012                           0.995154
# 9   0.651192  0.990895  0.657175   7.212012                           0.980826
# 10  0.645942  0.986536  0.654758   6.664883                           0.981336
# 11  0.197003  0.858570  0.229455   9.922948                           0.937003
# 12  0.028555  0.216781  0.131724   8.551594                           0.882312
# 13  0.001802  0.017990  0.100147  10.074259                           0.873232
# 14  0.015927  0.185539  0.085844  12.875809                           0.907393
# 15  0.000000  0.000000  0.000000   0.000000                           0.000000
# 16  0.000000  0.000000  0.000000   0.000000                           0.000000
# 17  0.000000  0.000000  0.000000   0.000000                           0.000000
# 18  0.000000  0.000000  0.000000   0.000000                           0.000000
# 19  0.000000  0.000000  0.000000   0.000000                           0.000000
# 20  0.000000  0.000000  0.000000   0.000000                           0.000000
