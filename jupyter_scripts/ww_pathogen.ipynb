# %%
import warnings
warnings.filterwarnings("ignore")

import os
import argparse
import sys
import subprocess
import math
import pickle
from collections import defaultdict
import json
import pandas as pd
import math
from ete3 import NCBITaxa
from Bio import SeqIO

# %%
from utils.reference_finder import prepare_reference_genomes
from utils.alignment import run_minimap2, sort_samfile, run_bwa, samtools_calculate_depth
from utils.summary import alignment_1_summary, alignment_2_summary, merge_reference_fasta, call_present_absent
from utils.ani import samtools_merged_consensus, ani_summary

# %%
def get_species_taxid(taxid, ncbi_taxa_db, valid_kingdom):
    lineage = ncbi_taxa_db.get_lineage(taxid)
    if bool(set(lineage) & valid_kingdom):
        taxid2rank_dict = ncbi_taxa_db.get_rank(lineage)
        for lineage_taxid in taxid2rank_dict:
            if taxid2rank_dict[lineage_taxid] == 'species':
                return lineage_taxid
    return None

# %%
def filter_kraken2_taxonomy(kraken2_report, min_frac, ncbi_taxa_db, valid_kingdom):
    classification_result_df = pd.read_csv(kraken2_report, sep='\t', names=['Abundance', 'Cumulative Count', 'Count', 'Rank', 'Taxid', 'Taxname']) 
    taxids = classification_result_df[(classification_result_df['Rank'] == 'S') & (classification_result_df['Abundance'] >= min_frac*100)]['Taxid'].tolist()
    valid_taxids = []
    for taxid in taxids:
        species_taxid = get_species_taxid(taxid, ncbi_taxa_db, valid_kingdom)
        if species_taxid is not None:
            valid_taxids.append(species_taxid)
    return valid_taxids

# %%
def get_pathogen_taxids(pathogen_list_f, ncbi_taxa_db, valid_kingdom):
    pathogen_df = pd.read_csv(pathogen_list_f)
    pathogen_df = pathogen_df.set_index('PathogenTaxID')
    valid_taxids = []
    for taxid in pathogen_df.index.to_list():
        species_taxid = get_species_taxid(taxid, ncbi_taxa_db, valid_kingdom)
        if species_taxid is not None:
            valid_taxids.append(species_taxid)
    return valid_taxids

# %%
def unzip_fastq(input_fastq, working_directory):
    temp_input_dir = os.path.join(working_directory, 'input_reads')
    if not os.path.exists(temp_input_dir):
        os.mkdir(temp_input_dir)
        
    subprocess.run(['cp',
                    input_fastq,
                    temp_input_dir],
                   check=True)
    
    filename = input_fastq.split('/')[-1]
    subprocess.run(['gunzip', '-d', os.path.join(temp_input_dir, filename)], check=True)
    
    filename = input_fastq.split('/')[-1][:-3]
    return os.path.join(temp_input_dir, filename)

# %%
ncbi_taxa_db = NCBITaxa()

# %%
input_fastq_1 = '/data/ww_data/final_ww_data/fastp/wastewater metagenome/SRR11088368_1.fastq.gz'
input_fastq_2 = '/data/ww_data/final_ww_data/fastp/wastewater metagenome/SRR11088368_2.fastq.gz'
kraken2_report = '/data/ww_data/final_ww_data/kraken/wastewater metagenome/SRR11088368_report.txt'
pathogen_list_f = '/home/Users/yl181/ww_pathogen/metadata/filtered_pathogen.csv'
working_directory = '/scratch0/yl181/ww_pathogen/test_run'
threads = 40
min_mapq = 20
min_coverage_score = 0.7
min_frac = 0.0005

# %%
if not os.path.exists(working_directory):
    os.mkdir(working_directory)

# %%
input_fastq_1 = unzip_fastq(input_fastq_1, working_directory)
# Out:
# gzip: /scratch0/yl181/ww_pathogen/test_run/input_reads/SRR11088368_1.fastq already exists;	not overwritten
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In [10], line 1
# ----> 1 input_fastq_1 = unzip_fastq(input_fastq_1, working_directory)
#
# Cell In [6], line 12, in unzip_fastq(input_fastq, working_directory)
#       6 subprocess.run(['cp',
#       7                 input_fastq,
#       8                 temp_input_dir],
#       9                check=True)
#      11 filename = input_fastq.split('/')[-1]
# ---> 12 subprocess.run(['gunzip', '-d', os.path.join(temp_input_dir, filename)], check=True)
#      14 filename = input_fastq.split('/')[-1][:-3]
#      15 return os.path.join(temp_input_dir, filename)
#
# File ~/miniconda3/envs/ww_pathogen/lib/python3.9/subprocess.py:528, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     526     retcode = process.poll()
#     527     if check and retcode:
# --> 528         raise CalledProcessError(retcode, process.args,
#     529                                  output=stdout, stderr=stderr)
#     530 return CompletedProcess(process.args, retcode, stdout, stderr)
#
# CalledProcessError: Command '['gunzip', '-d', '/scratch0/yl181/ww_pathogen/test_run/input_reads/SRR11088368_1.fastq.gz']' returned non-zero exit status 2.

# %%
input_fastq_2 = unzip_fastq(input_fastq_2, working_directory)

# %%
taxid_queries = filter_kraken2_taxonomy(kraken2_report,
                                        min_frac=min_frac, 
                                        ncbi_taxa_db=ncbi_taxa_db, 
                                        valid_kingdom={2, 4751, 2157, 10239})

# %%
len(taxid_queries)
# Out:
# 107

# %%
pathogen_taxids = get_pathogen_taxids(pathogen_list_f,
                                      ncbi_taxa_db=ncbi_taxa_db, 
                                      valid_kingdom={2, 4751, 2157, 10239})

# %%
taxid_queries = list(set(taxid_queries).intersection(set(pathogen_taxids)))

# %%
len(taxid_queries)
# Out:
# 30

# %%
reference_metadata = prepare_reference_genomes(taxid_queries, working_directory, ncbi_taxa_db)
# Out:
# 40324      	 GCF_900475405.1 	 Stenotrophomonas maltophilia   	 NCTC1025.. 	 Complete Genome
# 645        	 GCF_012931585.1 	 Aeromonas salmonicida          	 SRW-OG1    	 Complete Genome
# 651        	 GCF_020423125.1 	 Aeromonas media                	 TR3_1      	 Complete Genome
# 33039      	 GCA_023674525.1 	 [Ruminococcus] torques         	 NB2A-14-.. 	 Chromosome
# 1680       	 GCF_003030905.1 	 Bifidobacterium adolescentis   	 1-11       	 Complete Genome
# 40214      	 GCF_003335165.1 	 Acinetobacter johnsonii        	 LXL_C1     	 Complete Genome
# 40215      	 GCF_018336855.1 	 Acinetobacter junii            	 YR7        	 Complete Genome
# 2479767    	 GCF_005848555.1 	 Blautia sp. SC05B48            	 SC05B48    	 Complete Genome
# 2743575    	 GCF_013374795.1 	 Acinetobacter sp. NEB 394      	 NEB 394    	 Complete Genome
# 1307       	 GCF_000026745.1 	 Streptococcus suis BM407       	 BM407      	 Complete Genome
# 649756     	 GCF_001998765.1 	 Anaerostipes hadrus            	 BPB5       	 Complete Genome
# 285        	 GCF_014076415.1 	 Comamonas testosteroni         	 T5-67      	 Complete Genome
# 287        	 GCF_000006765.1 	 Pseudomonas aeruginosa PAO1    	 PAO1       	 Complete Genome
# 546        	 GCF_003812345.1 	 Citrobacter freundii           	 FDAARGOS.. 	 Complete Genome
# 28198      	 GCF_003660105.1 	 Aliarcobacter cryaerophilus .. 	 ATCC 431.. 	 Complete Genome
# 562        	 GCF_000008865.2 	 Escherichia coli O157:H7 str.. 	 Sakai su.. 	 Complete Genome
# 74426      	 GCF_002736145.1 	 Collinsella aerofaciens        	 indica     	 Complete Genome
# 165179     	 GCF_020735445.1 	 Prevotella copri DSM 18205     	 FDAARGOS.. 	 Complete Genome
# 573        	 GCF_000240185.1 	 Klebsiella pneumoniae subsp... 	 HS11286    	 Complete Genome
# 239935     	 GCF_009731575.1 	 Akkermansia muciniphila        	 JCM 3089.. 	 Complete Genome
# 225992     	 GCF_002056725.1 	 Comamonas kerstersii           	 8943       	 Complete Genome
# 237258     	 GCF_003860565.1 	 Cloacibacterium normanense     	 NRS-1      	 Complete Genome
# 853        	 GCF_002586945.1 	 Faecalibacterium prausnitzii   	 Indica     	 Complete Genome
# 470        	 GCF_008632635.1 	 Acinetobacter baumannii        	 K09-14     	 Complete Genome
# 166486     	 GCF_900537995.1 	 Roseburia intestinalis L1-82   	 L1-82      	 Complete Genome
# 410072     	 GCF_016904155.1 	 Coprococcus comes              	 FDAARGOS.. 	 Complete Genome
# 876        	 GCF_017815575.1 	 Desulfovibrio desulfuricans    	 L4         	 Complete Genome
# 216816     	 GCF_000196555.1 	 Bifidobacterium longum subsp.. 	 JCM 1217   	 Complete Genome
# 158836     	 GCF_019048625.1 	 Enterobacter hormaechei        	 FDAARGOS.. 	 Complete Genome
# 1463165    	 GCF_016415705.1 	 Klebsiella quasipneumoniae     	 KqPF26     	 Complete Genome
# 30 archives were successfully processed.

# %%
reference_metadata
# Out:
#     Taxonomy ID Assembly Accession ID          Source Database  \
# 0         40324       GCF_900475405.1   SOURCE_DATABASE_REFSEQ
# 1           645       GCF_012931585.1   SOURCE_DATABASE_REFSEQ
# 2           651       GCF_020423125.1   SOURCE_DATABASE_REFSEQ
# 3         33039       GCA_023674525.1  SOURCE_DATABASE_GENBANK
# 4          1680       GCF_003030905.1   SOURCE_DATABASE_REFSEQ
# 5         40214       GCF_003335165.1   SOURCE_DATABASE_REFSEQ
# 6         40215       GCF_018336855.1   SOURCE_DATABASE_REFSEQ
# 7       2479767       GCF_005848555.1   SOURCE_DATABASE_REFSEQ
# 8       2743575       GCF_013374795.1   SOURCE_DATABASE_REFSEQ
# 9          1307       GCF_000026745.1   SOURCE_DATABASE_REFSEQ
# 10       649756       GCF_001998765.1   SOURCE_DATABASE_REFSEQ
# 11          285       GCF_014076415.1   SOURCE_DATABASE_REFSEQ
# 12          287       GCF_000006765.1   SOURCE_DATABASE_REFSEQ
# 13          546       GCF_003812345.1   SOURCE_DATABASE_REFSEQ
# 14        28198       GCF_003660105.1   SOURCE_DATABASE_REFSEQ
# 15          562       GCF_000008865.2   SOURCE_DATABASE_REFSEQ
# 16        74426       GCF_002736145.1   SOURCE_DATABASE_REFSEQ
# 17       165179       GCF_020735445.1   SOURCE_DATABASE_REFSEQ
# 18          573       GCF_000240185.1   SOURCE_DATABASE_REFSEQ
# 19       239935       GCF_009731575.1   SOURCE_DATABASE_REFSEQ
# 20       225992       GCF_002056725.1   SOURCE_DATABASE_REFSEQ
# 21       237258       GCF_003860565.1   SOURCE_DATABASE_REFSEQ
# 22          853       GCF_002586945.1   SOURCE_DATABASE_REFSEQ
# 23          470       GCF_008632635.1   SOURCE_DATABASE_REFSEQ
# 24       166486       GCF_900537995.1   SOURCE_DATABASE_REFSEQ
# 25       410072       GCF_016904155.1   SOURCE_DATABASE_REFSEQ
# 26          876       GCF_017815575.1   SOURCE_DATABASE_REFSEQ
# 27       216816       GCF_000196555.1   SOURCE_DATABASE_REFSEQ
# 28       158836       GCF_019048625.1   SOURCE_DATABASE_REFSEQ
# 29      1463165       GCF_016415705.1   SOURCE_DATABASE_REFSEQ
#
#     Is Representative   Assembly Level  \
# 0                True  Complete Genome
# 1                True  Complete Genome
# 2                True  Complete Genome
# 3               False       Chromosome
# 4                True  Complete Genome
# 5               False  Complete Genome
# 6                True  Complete Genome
# 7               False  Complete Genome
# 8               False  Complete Genome
# 9                True  Complete Genome
# 10              False  Complete Genome
# 11              False  Complete Genome
# 12               True  Complete Genome
# 13               True  Complete Genome
# 14               True  Complete Genome
# 15               True  Complete Genome
# 16               True  Complete Genome
# 17               True  Complete Genome
# 18               True  Complete Genome
# 19               True  Complete Genome
# 20               True  Complete Genome
# 21               True  Complete Genome
# 22              False  Complete Genome
# 23               True  Complete Genome
# 24               True  Complete Genome
# 25               True  Complete Genome
# 26               True  Complete Genome
# 27               True  Complete Genome
# 28               True  Complete Genome
# 29               True  Complete Genome
#
#                                Organism of Assembly  \
# 0                      Stenotrophomonas maltophilia
# 1                             Aeromonas salmonicida
# 2                                   Aeromonas media
# 3                            [Ruminococcus] torques
# 4                      Bifidobacterium adolescentis
# 5                           Acinetobacter johnsonii
# 6                               Acinetobacter junii
# 7                               Blautia sp. SC05B48
# 8                         Acinetobacter sp. NEB 394
# 9                          Streptococcus suis BM407
# 10                              Anaerostipes hadrus
# 11                           Comamonas testosteroni
# 12                      Pseudomonas aeruginosa PAO1
# 13                             Citrobacter freundii
# 14           Aliarcobacter cryaerophilus ATCC 43158
# 15              Escherichia coli O157:H7 str. Sakai
# 16                          Collinsella aerofaciens
# 17                       Prevotella copri DSM 18205
# 18  Klebsiella pneumoniae subsp. pneumoniae HS11286
# 19                          Akkermansia muciniphila
# 20                             Comamonas kerstersii
# 21                       Cloacibacterium normanense
# 22                     Faecalibacterium prausnitzii
# 23                          Acinetobacter baumannii
# 24                     Roseburia intestinalis L1-82
# 25                                Coprococcus comes
# 26                      Desulfovibrio desulfuricans
# 27    Bifidobacterium longum subsp. longum JCM 1217
# 28                          Enterobacter hormaechei
# 29                       Klebsiella quasipneumoniae
#
#                         Strain  Total Length  Downloaded  \
# 0                    NCTC10258       4481118        True
# 1                      SRW-OG1       4621725        True
# 2                        TR3_1       4531033        True
# 3                  NB2A-14-FMU       2838928        True
# 4                         1-11       2192428        True
# 5                       LXL_C1       3398706        True
# 6                          YR7       3438557        True
# 7                      SC05B48       3731576        True
# 8                      NEB 394       3842079        True
# 9                        BM407       2170808        True
# 10                        BPB5       3172613        True
# 11                       T5-67       5947116        True
# 12                        PAO1       6264404        True
# 13                FDAARGOS_549       5102161        True
# 14                  ATCC 43158       2108340        True
# 15  Sakai substr. RIMD 0509952       5594605        True
# 16                      indica       2306349        True
# 17               FDAARGOS_1573       3551614        True
# 18                     HS11286       5682322        True
# 19                   JCM 30893       2878459        True
# 20                        8943       3547915        True
# 21                       NRS-1       2759562        True
# 22                      Indica       2868932        True
# 23                      K09-14       3980230        True
# 24                       L1-82       4493348        True
# 25               FDAARGOS_1339       3373067        True
# 26                          L4       3554892        True
# 27                    JCM 1217       2385164        True
# 28               FDAARGOS 1435       4762440        True
# 29                      KqPF26       5391123        True
#
#                          Species
# 0   Stenotrophomonas maltophilia
# 1          Aeromonas salmonicida
# 2                Aeromonas media
# 3         [Ruminococcus] torques
# 4   Bifidobacterium adolescentis
# 5        Acinetobacter johnsonii
# 6            Acinetobacter junii
# 7            Blautia sp. SC05B48
# 8      Acinetobacter sp. NEB 394
# 9             Streptococcus suis
# 10           Anaerostipes hadrus
# 11        Comamonas testosteroni
# 12        Pseudomonas aeruginosa
# 13          Citrobacter freundii
# 14   Aliarcobacter cryaerophilus
# 15              Escherichia coli
# 16       Collinsella aerofaciens
# 17              Prevotella copri
# 18         Klebsiella pneumoniae
# 19       Akkermansia muciniphila
# 20          Comamonas kerstersii
# 21    Cloacibacterium normanense
# 22  Faecalibacterium prausnitzii
# 23       Acinetobacter baumannii
# 24        Roseburia intestinalis
# 25             Coprococcus comes
# 26   Desulfovibrio desulfuricans
# 27        Bifidobacterium longum
# 28       Enterobacter hormaechei
# 29    Klebsiella quasipneumoniae

# %%
downloaded_assemblies = reference_metadata[reference_metadata['Downloaded']]

# %%
for assembly_id in downloaded_assemblies['Assembly Accession ID']:
    reference_fasta = os.path.join(working_directory, 'reference_genomes', f'{assembly_id}.fasta')
    run_bwa(input_fastq_1, input_fastq_2, reference_fasta, assembly_id, working_directory, threads=threads)
    sort_samfile(assembly_id, working_directory, min_mapq=min_mapq, threads=threads)
    samtools_calculate_depth(assembly_id, working_directory)

# %%
downloaded_assemblies = alignment_1_summary(downloaded_assemblies, working_directory)

# %%
filtered_assemblies = list(downloaded_assemblies[downloaded_assemblies['Coverage Score'] >= min_coverage_score]['Assembly Accession ID'])

# %%
reference_fasta = merge_reference_fasta(filtered_assemblies, working_directory)
run_bwa(input_fastq_1, input_fastq_2, reference_fasta, 'merged', working_directory, threads=threads)
sort_samfile('merged', working_directory, min_mapq=0, threads=threads)
samtools_calculate_depth('merged', working_directory)

# %%
downloaded_assemblies = alignment_2_summary(downloaded_assemblies, working_directory)

# %%
consensus_record_dict = samtools_merged_consensus(working_directory, threads)
downloaded_assemblies = ani_summary(downloaded_assemblies, consensus_record_dict, working_directory)

# %%
downloaded_assemblies = call_present_absent(downloaded_assemblies)

# %%
downloaded_assemblies.sort_values(['CS2'], ascending=False).to_csv(os.path.join(working_directory, 'reference_alignment.csv'), index=False)

# %%
downloaded_assemblies
# Out:
#     Taxonomy ID Assembly Accession ID  \
# 0         40324       GCF_900475405.1
# 1           645       GCF_012931585.1
# 2           651       GCF_020423125.1
# 3         33039       GCA_023674525.1
# 4          1680       GCF_003030905.1
# 5         40214       GCF_003335165.1
# 6         40215       GCF_018336855.1
# 7       2479767       GCF_005848555.1
# 8       2743575       GCF_013374795.1
# 9          1307       GCF_000026745.1
# 10       649756       GCF_001998765.1
# 11          285       GCF_014076415.1
# 12          287       GCF_000006765.1
# 13          546       GCF_003812345.1
# 14        28198       GCF_003660105.1
# 15          562       GCF_000008865.2
# 16        74426       GCF_002736145.1
# 17       165179       GCF_020735445.1
# 18          573       GCF_000240185.1
# 19       239935       GCF_009731575.1
# 20       225992       GCF_002056725.1
# 21       237258       GCF_003860565.1
# 22          853       GCF_002586945.1
# 23          470       GCF_008632635.1
# 24       166486       GCF_900537995.1
# 25       410072       GCF_016904155.1
# 26          876       GCF_017815575.1
# 27       216816       GCF_000196555.1
# 28       158836       GCF_019048625.1
# 29      1463165       GCF_016415705.1
#
#                                       Source Database  Is Representative  \
# 0                                         NCBI RefSeq               True
# 1                                         NCBI RefSeq               True
# 2                                         NCBI RefSeq               True
# 3                                                NCBI              False
# 4                                         NCBI RefSeq               True
# 5                                         NCBI RefSeq              False
# 6                                         NCBI RefSeq               True
# 7                                         NCBI RefSeq              False
# 8                                         NCBI RefSeq              False
# 9                                         NCBI RefSeq               True
# 10                                        NCBI RefSeq              False
# 11                                        NCBI RefSeq              False
# 12                           PathoGenesis Corporation               True
# 13                                        NCBI RefSeq               True
# 14                                        NCBI RefSeq               True
# 15                                               GIRC               True
# 16                                        NCBI RefSeq               True
# 17                                        NCBI RefSeq               True
# 18   Bioinformatics & Microbial Genomics, State Ke...               True
# 19                                        NCBI RefSeq               True
# 20                                        NCBI RefSeq               True
# 21                                        NCBI RefSeq               True
# 22                                        NCBI RefSeq              False
# 23                                        NCBI RefSeq               True
# 24                                        NCBI RefSeq               True
# 25                                        NCBI RefSeq               True
# 26                                        NCBI RefSeq               True
# 27                                        NCBI RefSeq               True
# 28                                        NCBI RefSeq               True
# 29                                        NCBI RefSeq               True
#
#      Assembly Level                             Organism of Assembly  \
# 0   Complete Genome                     Stenotrophomonas maltophilia
# 1   Complete Genome                            Aeromonas salmonicida
# 2   Complete Genome                                  Aeromonas media
# 3        Chromosome                           [Ruminococcus] torques
# 4   Complete Genome                     Bifidobacterium adolescentis
# 5   Complete Genome                          Acinetobacter johnsonii
# 6   Complete Genome                              Acinetobacter junii
# 7   Complete Genome                              Blautia sp. SC05B48
# 8   Complete Genome                        Acinetobacter sp. NEB 394
# 9   Complete Genome                         Streptococcus suis BM407
# 10  Complete Genome                              Anaerostipes hadrus
# 11  Complete Genome                           Comamonas testosteroni
# 12  Complete Genome                      Pseudomonas aeruginosa PAO1
# 13  Complete Genome                             Citrobacter freundii
# 14  Complete Genome           Aliarcobacter cryaerophilus ATCC 43158
# 15  Complete Genome              Escherichia coli O157:H7 str. Sakai
# 16  Complete Genome                          Collinsella aerofaciens
# 17  Complete Genome                       Prevotella copri DSM 18205
# 18  Complete Genome  Klebsiella pneumoniae subsp. pneumoniae HS11286
# 19  Complete Genome                          Akkermansia muciniphila
# 20  Complete Genome                             Comamonas kerstersii
# 21  Complete Genome                       Cloacibacterium normanense
# 22  Complete Genome                     Faecalibacterium prausnitzii
# 23  Complete Genome                          Acinetobacter baumannii
# 24  Complete Genome                     Roseburia intestinalis L1-82
# 25  Complete Genome                                Coprococcus comes
# 26  Complete Genome                      Desulfovibrio desulfuricans
# 27  Complete Genome    Bifidobacterium longum subsp. longum JCM 1217
# 28  Complete Genome                          Enterobacter hormaechei
# 29  Complete Genome                       Klebsiella quasipneumoniae
#
#                         Strain  Downloaded                       Species  \
# 0                    NCTC10258        True  Stenotrophomonas maltophilia
# 1                      SRW-OG1        True         Aeromonas salmonicida
# 2                        TR3_1        True               Aeromonas media
# 3                  NB2A-14-FMU        True        [Ruminococcus] torques
# 4                         1-11        True  Bifidobacterium adolescentis
# 5                       LXL_C1        True       Acinetobacter johnsonii
# 6                          YR7        True           Acinetobacter junii
# 7                      SC05B48        True           Blautia sp. SC05B48
# 8                      NEB 394        True     Acinetobacter sp. NEB 394
# 9                        BM407        True            Streptococcus suis
# 10                        BPB5        True           Anaerostipes hadrus
# 11                       T5-67        True        Comamonas testosteroni
# 12                        PAO1        True        Pseudomonas aeruginosa
# 13                FDAARGOS_549        True          Citrobacter freundii
# 14                  ATCC 43158        True   Aliarcobacter cryaerophilus
# 15  Sakai substr. RIMD 0509952        True              Escherichia coli
# 16                      indica        True       Collinsella aerofaciens
# 17               FDAARGOS_1573        True              Prevotella copri
# 18                     HS11286        True         Klebsiella pneumoniae
# 19                   JCM 30893        True       Akkermansia muciniphila
# 20                        8943        True          Comamonas kerstersii
# 21                       NRS-1        True    Cloacibacterium normanense
# 22                      Indica        True  Faecalibacterium prausnitzii
# 23                      K09-14        True       Acinetobacter baumannii
# 24                       L1-82        True        Roseburia intestinalis
# 25               FDAARGOS_1339        True             Coprococcus comes
# 26                          L4        True   Desulfovibrio desulfuricans
# 27                    JCM 1217        True        Bifidobacterium longum
# 28               FDAARGOS 1435        True       Enterobacter hormaechei
# 29                      KqPF26        True    Klebsiella quasipneumoniae
#
#     Breadth Coverage  Expected Coverage  Coverage Score  Depth Coverage  \
# 0           0.839573           1.000000        0.839573       34.563671
# 1           0.841355           0.999998        0.841356       15.705711
# 2           0.871588           1.000000        0.871588       18.324055
# 3           0.638248           0.999997        0.638250       20.186668
# 4           0.969784           1.000000        0.969784       49.626209
# 5           0.955982           1.000000        0.955982       79.342853
# 6           0.703081           1.000000        0.703081       32.917163
# 7           0.939978           1.000000        0.939978       28.135163
# 8           0.959521           1.000000        0.959521       79.441439
# 9           0.641112           0.999732        0.641284       12.830374
# 10          0.955947           1.000000        0.955947       23.247111
# 11          0.729633           1.000000        0.729633       53.984637
# 12          0.750096           1.000000        0.750096       23.007642
# 13          0.916487           1.000000        0.916487       26.468455
# 14          0.932623           1.000000        0.932623       20.159384
# 15          0.896436           1.000000        0.896436       42.209379
# 16          0.944198           1.000000        0.944198       32.480432
# 17          0.741253           0.995963        0.744258        7.436305
# 18          0.951345           1.000000        0.951345       30.103833
# 19          0.983008           1.000000        0.983008       51.916972
# 20          0.733389           1.000000        0.733389       67.342723
# 21          0.908765           0.999990        0.908774       12.638790
# 22          0.965445           1.000000        0.965445       47.055026
# 23          0.575722           1.000000        0.575722       27.502425
# 24          0.613842           0.999998        0.613843       21.759672
# 25          0.928913           1.000000        0.928913       22.712329
# 26          0.871071           0.999988        0.871081       13.015867
# 27          0.944944           1.000000        0.944944       36.286933
# 28          0.913310           1.000000        0.913310       27.952961
# 29          0.968364           1.000000        0.968364       30.549331
#
#          BC2       EC2       CS2        DC2  Consensus ANI  \
# 0   0.814941  1.000000  0.814941  23.577827       0.981539
# 1   0.718890  0.986014  0.729087   5.939255       0.987220
# 2   0.842731  0.998330  0.844141   7.588203       0.983200
# 3   0.000000  0.000000  0.000000   0.000000       0.000000
# 4   0.970498  1.000000  0.970498  39.889433       0.995705
# 5   0.974916  1.000000  0.974916  33.517974       0.989357
# 6   0.671086  0.999798  0.671221  12.675992       0.955793
# 7   0.954549  1.000000  0.954549  23.922561       0.983677
# 8   0.990409  1.000000  0.990409  56.647163       0.995534
# 9   0.000000  0.000000  0.000000   0.000000       0.000000
# 10  0.973811  1.000000  0.973811  19.278097       0.995118
# 11  0.700041  1.000000  0.700041  40.119623       0.968364
# 12  0.704004  0.999804  0.704142  12.128048       0.989756
# 13  0.892323  0.998064  0.894054   7.000806       0.985482
# 14  0.945659  1.000000  0.945659  18.186905       0.977474
# 15  0.916219  1.000000  0.916219  33.477121       0.990711
# 16  0.954109  1.000000  0.954109  26.068877       0.980516
# 17  0.746695  0.986719  0.756745   5.787401       0.986355
# 18  0.958143  0.999979  0.958164  11.217542       0.995492
# 19  0.994885  1.000000  0.994885  49.239218       0.996074
# 20  0.694253  1.000000  0.694253  39.381015       0.965437
# 21  0.914433  0.999949  0.914480  10.808966       0.985893
# 22  0.974128  1.000000  0.974128  41.691542       0.989486
# 23  0.000000  0.000000  0.000000   0.000000       0.000000
# 24  0.000000  0.000000  0.000000   0.000000       0.000000
# 25  0.931943  1.000000  0.931943  16.955882       0.992883
# 26  0.872297  0.999341  0.872873   8.397204       0.979759
# 27  0.958789  1.000000  0.958789  22.268293       0.997280
# 28  0.882106  0.999063  0.882933   7.904936       0.986232
# 29  0.936350  0.999623  0.936703   8.418771       0.990976
#
#     Combined CS2 and ANI (Sqrt(ANI)xCS2x100) Presence/Absence
# 0                                      80.74          Present
# 1                                      72.44          Present
# 2                                      83.70          Present
# 3                                       0.00           Absent
# 4                                      96.84          Present
# 5                                      96.97          Present
# 6                                      65.62          Present
# 7                                      94.67          Present
# 8                                      98.82          Present
# 9                                       0.00           Absent
# 10                                     97.14          Present
# 11                                     68.89          Present
# 12                                     70.05          Present
# 13                                     88.75          Present
# 14                                     93.49          Present
# 15                                     91.20          Present
# 16                                     94.48          Present
# 17                                     75.16          Present
# 18                                     95.60          Present
# 19                                     99.29          Present
# 20                                     68.22          Present
# 21                                     90.80          Present
# 22                                     96.90          Present
# 23                                      0.00           Absent
# 24                                      0.00           Absent
# 25                                     92.86          Present
# 26                                     86.40          Present
# 27                                     95.75          Present
# 28                                     87.68          Present
# 29                                     93.25          Present
